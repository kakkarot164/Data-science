# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1 - Business Problem

# %% [markdown]
# <h3 style="color:blue; font-family: Arial;">Prepare a model for glass classification using KNN</h3>

# %% [markdown]
# # 2 - Data collection and description

# %%
df = pd.read_csv("glass.csv")
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
# check for null 
df.isna().any()
# Out:
# RI      False
# Na      False
# Mg      False
# Al      False
# Si      False
# K       False
# Ca      False
# Ba      False
# Fe      False
# Type    False
# dtype: bool

# %% [markdown]
# <span style="color:red; font-family: Arial;">Type: Type of glass: (class attribute)</span>
#
# 1 -- building_windows_float_processed
#
#  2 --building_windows_non_float_processed
#
#  3 --vehicle_windows_float_processed
#
#  4 --vehicle_windows_non_float_processed (none in this database)
#
#  5 --containers
#
#  6 --tableware
#
#  7 --headlamps

# %%
sns.countplot(df,x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %% [markdown]
# <h2 style="color:blue; font-family: Arial;">Conclusion:</h2>

# %% [markdown]
# <h3 style="color:black; font-family: Arial;"> As shown in the graphs above, majority of the glass types are building_windows_float_processed and building_windows_non_float_processed, followed by headlamps</h3>

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# # 3 - Finding correlation between the variables in the data

# %%
cor = df.corr(method='pearson')

# %%
cor.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1f69d_row0_col0, #T_1f69d_row1_col1, #T_1f69d_row2_col2, #T_1f69d_row3_col3, #T_1f69d_row4_col4, #T_1f69d_row5_col5, #T_1f69d_row6_col6, #T_1f69d_row7_col7, #T_1f69d_row8_col8, #T_1f69d_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col2 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_1f69d_row0_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col4, #T_1f69d_row1_col8, #T_1f69d_row2_col1, #T_1f69d_row2_col3, #T_1f69d_row2_col6, #T_1f69d_row2_col7, #T_1f69d_row2_col9, #T_1f69d_row4_col0, #T_1f69d_row6_col1, #T_1f69d_row6_col5, #T_1f69d_row9_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col6 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_1f69d_row0_col7, #T_1f69d_row4_col2 {
# ...

# %% [markdown]
# <h3 style="color:black; font-family: Arial;"> As seen in the above graph, there is a high correlation exists between some of the variables. We can use PCA to reduce the hight correlated variables</h3>

# %% [markdown]
# # 4 - KNN

# %% [markdown]
# Finding optimal number of K

# %%
X = np.array(df.iloc[:,3:5])
y = np.array(df['Type'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

# %%
k_values = np.arange(1,25)
train_accuracy = []
test_accuracy = []

# %%
for i, k in enumerate(k_values):
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train,y_train)
    train_accuracy.append(knn.score(X_train, y_train))
    test_accuracy.append(knn.score(X_test, y_test))

# %%
plt.figure(figsize=[13,8])
plt.plot(k_values, test_accuracy, label = 'Testing Accuracy')
plt.plot(k_values, train_accuracy, label = 'Training Accuracy')
plt.legend()
plt.title('-value VS Accuracy')
plt.xlabel('Number of Neighbors')
plt.ylabel('Accuracy')
plt.xticks(k_values)
plt.show()

# %% [markdown]
# <h2 style="color:black; font-family: Arial;"> we can see that k=4 produces the most accurate results</h2>

# %% [markdown]
# Applying the algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train, y_train)
y_pred_KNeighborsClassifier = knn.predict(X_test)

# %%
scores = []
cv_scores = []

# %%
score = accuracy_score(y_pred_KNeighborsClassifier,y_test)
scores.append(score)

# %%
score_knn=cross_val_score(knn, X,y, cv=10)

# %%
score_knn.mean()
# Out:
# 0.6127705627705629

# %%
score_knn.std()*2
# Out:
# 0.23547117559816877

# %%
cv_score = score_knn.mean()

# %%
cv_scores.append(cv_score)

# %%
cv_scores
# Out:
# [0.6127705627705629]

# %% [markdown]
# # 5 - Final Conclusion

# %% [markdown]
# <h3 style="color:blue; font-family: Arial;">Support Vector Machine Accuracy: 0.60 (+/- 0.21)</h3>
