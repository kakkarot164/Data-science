# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report , confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #  Business Problem

# %% [markdown]
# <h3 style="color:blue; font-family: Arial;"> Implement a KNN model to classify the animals in to categorie</h3>

# %% [markdown]
# # Data collection and description

# %%
df = pd.read_csv('./Zoo.csv',index_col=0) # set animal name to index since it is not required for classification
df
# Out:
#              hair  feathers  eggs  milk  airborne  aquatic  predator  toothed  \
# animal name
# aardvark        1         0     0     1         0        0         1        1
# antelope        1         0     0     1         0        0         0        1
# bass            0         0     1     0         0        1         1        1
# bear            1         0     0     1         0        0         1        1
# boar            1         0     0     1         0        0         1        1
# ...           ...       ...   ...   ...       ...      ...       ...      ...
# wallaby         1         0     0     1         0        0         0        1
# wasp            1         0     1     0         1        0         0        0
# wolf            1         0     0     1         0        0         1        1
# worm            0         0     1     0         0        0         0        0
# wren            0         1     1     0         1        0         0        0
#
#              backbone  breathes  venomous  fins  legs  tail  domestic  \
# animal name
# aardvark            1         1         0     0     4     0         0
# antelope            1         1         0     0     4     1         0
# bass                1         0         0     1     0     1         0
# bear                1         1         0     0     4     0         0
# boar                1         1         0     0     4     1         0
# ...               ...       ...       ...   ...   ...   ...       ...
# wallaby             1         1         0     0     2     1         0
# wasp                0         1         1     0     6     0         0
# wolf                1         1         0     0     4     1         0
# worm                0         1         0     0     0     0         0
# wren                1         1         0     0     2     1         0
#
#              catsize  type
# animal name
# aardvark           1     1
# antelope           1     1
# bass               0     4
# bear               1     1
# boar               1     1
# ...              ...   ...
# wallaby            1     1
# wasp               0     6
# wolf               1     1
# worm               0     7
# wren               0     2
#
# [101 rows x 17 columns]

# %%
df.describe()
# Out:
#              hair    feathers        eggs        milk    airborne     aquatic  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.425743    0.198020    0.584158    0.405941    0.237624    0.356436
# std      0.496921    0.400495    0.495325    0.493522    0.427750    0.481335
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 50%      0.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 75%      1.000000    0.000000    1.000000    1.000000    0.000000    1.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#          predator     toothed    backbone    breathes    venomous        fins  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     0.554455    0.603960    0.821782    0.792079    0.079208    0.168317
# std      0.499505    0.491512    0.384605    0.407844    0.271410    0.376013
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    1.000000    1.000000    0.000000    0.000000
# 50%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# 75%      1.000000    1.000000    1.000000    1.000000    0.000000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#              legs        tail    domestic     catsize        type
# count  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     2.841584    0.742574    0.128713    0.435644    2.831683
# std      2.033385    0.439397    0.336552    0.498314    2.102709
# min      0.000000    0.000000    0.000000    0.000000    1.000000
# 25%      2.000000    0.000000    0.000000    0.000000    1.000000
# 50%      4.000000    1.000000    0.000000    0.000000    2.000000
# 75%      4.000000    1.000000    0.000000    1.000000    4.000000
# max      8.000000    1.000000    1.000000    1.000000    7.000000

# %%
# check for null 
df.isna().any()
# Out:
# hair        False
# feathers    False
# eggs        False
# milk        False
# airborne    False
# aquatic     False
# predator    False
# toothed     False
# backbone    False
# breathes    False
# venomous    False
# fins        False
# legs        False
# tail        False
# domestic    False
# catsize     False
# type        False
# dtype: bool

# %%
sns.countplot(df,x='type')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %% [markdown]
# <h2 style="color:blue; font-family: Arial;">Conclusion:</h2>

# %% [markdown]
# <h3 style="color:black; font-family: Arial;"> As shown in the graphs above, highest number of animals available in Zoo are Type 1 followed by 2, 4 and 7 respectively</h3>

# %%
df.plot(kind='density', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %%
df.plot(kind='box', subplots=True, layout=(4,5), figsize=(13,20), sharex=False, sharey=False)
plt.show()

# %% [markdown]
# <h2 style="color:blue; font-family: Arial;">Conclusion:</h2>

# %% [markdown]
# <h3 style="color:black; font-family: Arial;"> As shown in the graphs above, majority of the variables are evenly distributed amongst the animals. However some of the variables like feathers, airbone, backbone, breathes, venomous, fins and domestic is not evenly distributed (i.e majority of animals either have these variable or dont)</h3>

# %% [markdown]
# # KNN

# %%
X = df.drop('type',axis=1)
Y = df['type']

# %%
# perform scaling
sc = StandardScaler()
scaled = sc.fit_transform(X)
scaled
# Out:
# array([[ 1.16139451, -0.49690399, -1.18522652, ..., -1.69841555,
#         -0.38435306,  1.13818037],
#        [ 1.16139451, -0.49690399, -1.18522652, ...,  0.58878406,
#         -0.38435306,  1.13818037],
#        [-0.86103386, -0.49690399,  0.84372057, ...,  0.58878406,
#         -0.38435306, -0.87859537],
#        ...,
#        [ 1.16139451, -0.49690399, -1.18522652, ...,  0.58878406,
#         -0.38435306,  1.13818037],
#        [-0.86103386, -0.49690399,  0.84372057, ..., -1.69841555,
#         -0.38435306, -0.87859537],
#        [-0.86103386,  2.01246118,  0.84372057, ...,  0.58878406,
#         -0.38435306, -0.87859537]])

# %%
# split the data
xtrain , xtest , ytrain , ytest = train_test_split(scaled,Y,test_size=0.2,random_state=42)

# %%
knn = KNeighborsClassifier().fit(xtrain,ytrain)

# %%
print('\033[91m Train Report')
print(classification_report(ytrain,knn.predict(xtrain)))
# Out:
#  Train Report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       0.95      1.00      0.97        18
#            3       1.00      0.75      0.86         4
#            4       1.00      1.00      1.00        11
#            5       1.00      1.00      1.00         4
#            6       0.83      1.00      0.91         5
#            7       1.00      0.89      0.94         9
#
#     accuracy                           0.97        80
#    macro avg       0.97      0.95      0.95        80
# weighted avg       0.98      0.97      0.97        80

# %%
ypred = knn.predict(xtest)

# %%
print('\033[92m Test Report')
print(classification_report(ytest,ypred))
# Out:
#  Test Report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         2
#            3       0.00      0.00      0.00         1
#            4       0.67      1.00      0.80         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         1
#
#     accuracy                           0.95        21
#    macro avg       0.78      0.83      0.80        21
# weighted avg       0.92      0.95      0.93        21

# %%
print('Training accuracy: ', knn.score(xtrain,ytrain))
print('Testing Accuracy: ', knn.score(xtest,ytest))
# Out:
# Training accuracy:  0.975
# Testing Accuracy:  0.9523809523809523

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.title('Confusion Matrix')
plt.ylabel('True Value')
plt.xlabel('Predicted Value')
plt.show()

# %% [markdown]
# The Model is generalized but i will still show how to finetune the model

# %% [markdown]
# # Hyper parameter Tuning

# %%
train_acc = []
test_acc = []
for i in range(1,50):
    tknn = KNeighborsClassifier(n_neighbors=i)
    tknn.fit(xtrain,ytrain)
    print(f'For neighbour = {i}')
    print(f"Train Accuracy : {tknn.score(xtrain,ytrain)}")
    print(f"Test Accuracy : {tknn.score(xtest,ytest)} \n")
    train_acc.append(tknn.score(xtrain,ytrain))
    test_acc.append(tknn.score(xtest,ytest))
# Out:
# For neighbour = 1
# Train Accuracy : 1.0
# Test Accuracy : 1.0
#
# For neighbour = 2
# Train Accuracy : 0.95
# Test Accuracy : 1.0
#
# For neighbour = 3
# Train Accuracy : 0.975
# Test Accuracy : 1.0
#
# For neighbour = 4
# Train Accuracy : 0.9375
# Test Accuracy : 0.9523809523809523
#
# For neighbour = 5
# Train Accuracy : 0.975
# Test Accuracy : 0.9523809523809523
#
# For neighbour = 6
# Train Accuracy : 0.95
# Test Accuracy : 0.9523809523809523
#
# For neighbour = 7
# Train Accuracy : 0.975
# Test Accuracy : 0.9523809523809523
#
# For neighbour = 8
# Train Accuracy : 0.95
# Test Accuracy : 0.9523809523809523
#
# For neighbour = 9
# Train Accuracy : 0.9375
# Test Accuracy : 0.9047619047619048
#
# For neighbour = 10
# Train Accuracy : 0.9375
# Test Accuracy : 0.9047619047619048
#
# For neighbour = 11
# Train Accuracy : 0.8625
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 12
# Train Accuracy : 0.8625
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 13
# Train Accuracy : 0.85
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 14
# Train Accuracy : 0.8625
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 15
# Train Accuracy : 0.8625
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 16
# Train Accuracy : 0.8625
# Test Accuracy : 0.8571428571428571
#
# For neighbour = 17
# Train Accuracy : 0.85
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 18
# Train Accuracy : 0.85
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 19
# Train Accuracy : 0.85
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 20
# Train Accuracy : 0.8375
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 21
# Train Accuracy : 0.8375
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 22
# Train Accuracy : 0.8375
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 23
# Train Accuracy : 0.825
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 24
# Train Accuracy : 0.8
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 25
# Train Accuracy : 0.8
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 26
# Train Accuracy : 0.8
# Test Accuracy : 0.8095238095238095
#
# For neighbour = 27
# Train Accuracy : 0.8
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 28
# Train Accuracy : 0.8
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 29
# Train Accuracy : 0.8
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 30
# Train Accuracy : 0.8
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 31
# Train Accuracy : 0.7875
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 32
# Train Accuracy : 0.7625
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 33
# Train Accuracy : 0.7625
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 34
# Train Accuracy : 0.7375
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 35
# Train Accuracy : 0.7375
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 36
# Train Accuracy : 0.7375
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 37
# Train Accuracy : 0.7375
# Test Accuracy : 0.7619047619047619
#
# For neighbour = 38
# Train Accuracy : 0.7125
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 39
# Train Accuracy : 0.7125
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 40
# Train Accuracy : 0.6875
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 41
# Train Accuracy : 0.6875
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 42
# Train Accuracy : 0.6875
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 43
# Train Accuracy : 0.6375
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 44
# Train Accuracy : 0.6375
# Test Accuracy : 0.7142857142857143
#
# For neighbour = 45
# Train Accuracy : 0.5875
# Test Accuracy : 0.6666666666666666
#
# For neighbour = 46
# Train Accuracy : 0.575
# Test Accuracy : 0.6666666666666666
#
# For neighbour = 47
# Train Accuracy : 0.575
# Test Accuracy : 0.6666666666666666
#
# For neighbour = 48
# Train Accuracy : 0.575
# Test Accuracy : 0.6666666666666666
#
# For neighbour = 49
# Train Accuracy : 0.5625
# Test Accuracy : 0.6666666666666666

# %%
plt.plot(range(1,50),train_acc,color='blue',label='train accuracy')
plt.plot(range(1,50),test_acc,color='red',label='test accuracy')
plt.xlabel('K-neighbour')
plt.ylabel('Accuracy')
plt.axvline(8)
plt.legend()
plt.title('K-Value Selection')
plt.show()

# %% [markdown]
# Using n=8 since line intersect and accuracy is also high

# %% [markdown]
# # Final Model

# %%
fknn = KNeighborsClassifier(n_neighbors=8).fit(xtrain,ytrain)

# %%
print('\033[91m Train Report')
print(classification_report(ytrain,fknn.predict(xtrain)))
# Out:
#  Train Report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        29
#            2       0.95      1.00      0.97        18
#            3       1.00      0.75      0.86         4
#            4       1.00      1.00      1.00        11
#            5       1.00      1.00      1.00         4
#            6       0.62      1.00      0.77         5
#            7       1.00      0.67      0.80         9
#
#     accuracy                           0.95        80
#    macro avg       0.94      0.92      0.91        80
# weighted avg       0.96      0.95      0.95        80

# %%
print('\033[92m Test Report')
print(classification_report(ytest,fknn.predict(xtest)))
# Out:
#  Test Report
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         2
#            3       0.00      0.00      0.00         1
#            4       0.67      1.00      0.80         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         1
#
#     accuracy                           0.95        21
#    macro avg       0.78      0.83      0.80        21
# weighted avg       0.92      0.95      0.93        21

# %%
print('Training accuracy: ', fknn.score(xtrain,ytrain))
print('Testing Accuracy: ', fknn.score(xtest,ytest))
# Out:
# Training accuracy:  0.95
# Testing Accuracy:  0.9523809523809523

# %%
sns.heatmap(confusion_matrix(ytest,fknn.predict(xtest)),annot=True)
plt.title('Confusion Matrix')
plt.ylabel('True Value')
plt.xlabel('Predicted Value')
plt.show()

# %% [markdown]
# Same performance as base model
